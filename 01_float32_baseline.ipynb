# %%
import importlib
import utils

# Reload utils module
importlib.reload(utils)

# import 
from utils import *

# %%
model = ResNet18().to(device) 
optimizer = optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss()

# %%
epochs = 20
for epoch in range(epochs):
    model.train()
    acc = evaluate(model)
    for x, y in train_loader:
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        loss = criterion(model(x),y)
        loss.backward()
        optimizer.step()
    
    #acc = evaluate(model)
    print(f"Epoch {epoch+1}/{epochs} - Test Acc: {acc:.2f}%")
# Out:
# Epoch 1/30 - Test Acc: 8.92%
# Epoch 2/30 - Test Acc: 98.25%
# Epoch 3/30 - Test Acc: 98.74%
# Epoch 4/30 - Test Acc: 99.09%
# Epoch 5/30 - Test Acc: 98.91%
# Epoch 6/30 - Test Acc: 99.03%
# Epoch 7/30 - Test Acc: 98.80%
# Epoch 8/30 - Test Acc: 99.12%
# Epoch 9/30 - Test Acc: 98.98%
# Epoch 10/30 - Test Acc: 99.03%
# Epoch 11/30 - Test Acc: 98.52%
# Epoch 12/30 - Test Acc: 99.13%
# Epoch 13/30 - Test Acc: 99.21%
# Epoch 14/30 - Test Acc: 99.10%
# Epoch 15/30 - Test Acc: 99.11%
# Epoch 16/30 - Test Acc: 99.12%
# Epoch 17/30 - Test Acc: 99.09%
# Epoch 18/30 - Test Acc: 99.01%
# Epoch 19/30 - Test Acc: 99.18%
# Epoch 20/30 - Test Acc: 99.19%
# Epoch 21/30 - Test Acc: 99.17%
# Epoch 22/30 - Test Acc: 99.17%
# Epoch 23/30 - Test Acc: 99.22%
# Epoch 24/30 - Test Acc: 98.81%
# Epoch 25/30 - Test Acc: 99.23%
# Epoch 26/30 - Test Acc: 99.15%
# Epoch 27/30 - Test Acc: 99.20%
# Epoch 28/30 - Test Acc: 99.31%
# Epoch 29/30 - Test Acc: 99.27%
# Epoch 30/30 - Test Acc: 99.36%

# %% [markdown]
# ### Print Result & Save

# %%
print(f"Final Accuracy: {evaluate(model): .2f}%")
print(f"Model Size: {get_float_model_size(model):.2f} MB")
print(f"Inference Time: {measure_inference_time(model):.3f} ms/image")
torch.save(model.state_dict(), "resnet18_float32.pth")
# Out:
# Final Accuracy:  99.25%
# Model Size: 44.76 MB
# Inference Time: 0.012 ms/image
